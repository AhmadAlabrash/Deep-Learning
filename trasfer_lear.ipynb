# %%
import numpy as np
import cv2
import os
import matplotlib.pylab as plt
import tensorflow as tf
import tensorflow_hub as hub

# %%
classifier = tf.keras.Sequential([
    hub.KerasLayer("https://tfhub.dev/google/tf2-preview/mobilenet_v2/classification/4",input_shape=(224,224,3))])

# %%
IMAGE_SHAPE = (224, 224)

classifier = tf.keras.Sequential([
    hub.KerasLayer("https://tfhub.dev/google/tf2-preview/mobilenet_v2/classification/4", input_shape=(224,224,3,))
])

# %%
import PIL.Image as Image
gold_fish = Image.open("download.jpg").resize(IMAGE_SHAPE)
gold_fish
# Out:
# <PIL.Image.Image image mode=RGB size=224x224 at 0x7FE346C01850>
