# %% [markdown]
# <a href="https://colab.research.google.com/github/AhmadAlabrash/Deep-Learning/blob/main/faceDetect.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install opencv-python
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
pip install pep8
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 41 kB 350 kB/s
# ...

# %%
pip install --upgrade pep8
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
import cv2
import matplotlib.pyplot as plt
from google.colab.patches import cv2_imshow

# %%
face_detect = cv2.CascadeClassifier("haarcascade_frontalface_default.xml")
fr =cv2.imread('2.jpg')
fr
# Out:
# array([[[145, 156, 164],
#         [145, 156, 164],
#         [145, 156, 164],
#         ...,
#         [130, 138, 137],
#         [132, 140, 139],
#         [135, 143, 142]],
#
#        [[145, 156, 164],
#         [145, 156, 164],
#         [145, 156, 164],
#         ...,
#         [130, 138, 137],
#         [132, 140, 139],
#         [135, 143, 142]],
#
#        [[145, 156, 164],
#         [145, 156, 164],
#         [145, 157, 163],
#         ...,
#         [130, 138, 137],
#         [132, 140, 139],
#         [135, 143, 142]],
#
#        ...,
#
#        [[  0,   0,   0],
#         [  0,   0,   0],
#         [  0,   0,   0],
#         ...,
#         [107, 114, 101],
#         [109, 116, 103],
#         [111, 118, 105]],
#
#        [[  0,   0,   1],
#         [  0,   0,   1],
#         [  0,   1,   2],
#         ...,
#         [107, 114, 101],
#         [109, 116, 103],
#         [111, 118, 105]],
#
#        [[  0,   1,   2],
#         [  0,   1,   2],
#         [  0,   1,   2],
# ...

# %%
gray_frame = cv2.cvtColor(fr,cv2.COLOR_BGR2GRAY)


    
faces = face_detect.detectMultiScale(gray_frame,1.3,5)
for (x,y,w,h) in faces:
        cv2.rectangle(fr,(x,y),(x+w,y+h),(0,255,0),2)

# %%
cv2_imshow( fr)
# Out:
# <PIL.Image.Image image mode=RGB size=1280x720 at 0x7F458A79F490>

# %%
def faceDetect (img):
  import cv2
  import matplotlib.pyplot as plt
  from google.colab.patches import cv2_imshow
  face_detect = cv2.CascadeClassifier("haarcascade_frontalface_default.xml")
  fr =cv2.imread(img)
  gray_frame = cv2.cvtColor(fr,cv2.COLOR_BGR2GRAY)

    
  faces = face_detect.detectMultiScale(gray_frame,1.3,5)

  for (x,y,w,h) in faces:
        cv2.rectangle(fr,(x,y),(x+w,y+h),(0,255,0),2)
  return cv2_imshow(fr)

# %%
faceDetect("4.jpg")
# Out:
# <PIL.Image.Image image mode=RGB size=680x383 at 0x7F458BAF3350>
