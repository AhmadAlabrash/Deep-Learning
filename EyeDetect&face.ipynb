# %% [markdown]
# <a href="https://colab.research.google.com/github/AhmadAlabrash/Deep-Learning/blob/main/EyeDetect%26face.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install pep8
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 41 kB 405 kB/s
# ...

# %%
def EyeDetect (img):
  import cv2
  import matplotlib.pyplot as plt
  from google.colab.patches import cv2_imshow
  face_detect = cv2.CascadeClassifier("haarcascade_frontalface_default.xml")
  eye_detect = cv2.CascadeClassifier("haarcascade_eye.xml")
  fr =cv2.imread(img)
  gray_frame = cv2.cvtColor(fr,cv2.COLOR_BGR2GRAY)

    
  faces = face_detect.detectMultiScale(gray_frame,1.3,5)

  for (x,y,w,h) in faces:
        cv2.rectangle(fr,(x,y),(x+w,y+h),(0,255,0),2) 
        face_only = fr[y:y+h,x:x+w]
        
############# eye detect        

        eyes = eye_detect.detectMultiScale(face_only)
        for (ex,ey,ew,eh) in eyes:
            eye_x = int((ex+(ew/2))) - 10
            eye_y = int((ey+(eh/2))) + 10
            cv2.putText(face_only,"X",(eye_x,eye_y),cv2.FONT_HERSHEY_COMPLEX,1.5,(0,0,255),5)

  return cv2_imshow(fr)

# %%
EyeDetect("4.jpg")
# Out:
# <PIL.Image.Image image mode=RGB size=225x225 at 0x7FD03E8F3250>
