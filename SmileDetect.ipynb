# %% [markdown]
# <a href="https://colab.research.google.com/github/AhmadAlabrash/Deep-Learning/blob/main/SmileDetect.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def SmileDetect (img):
  import cv2
  import matplotlib.pyplot as plt
  from google.colab.patches import cv2_imshow
  face_detect = cv2.CascadeClassifier("haarcascade_frontalface_default.xml")
  smile_detect = cv2.CascadeClassifier("haarcascade_smile.xml")
  fr =cv2.imread(img)
  gray_frame = cv2.cvtColor(fr,cv2.COLOR_BGR2GRAY)

    
  faces = face_detect.detectMultiScale(gray_frame,1.3,5)

  for (x,y,w,h) in faces:
        cv2.rectangle(fr,(x,y),(x+w,y+h),(0,255,0),2) 
        face_only = fr[y:y+h,x:x+w]
        
  smiles = smile_detect.detectMultiScale(face_only,1.3,10)
  for (sx,sy,sw,sh) in smiles:
        cv2.rectangle(face_only,(sx,sy),(sx+sw,sy+sh),(255,0,0),2)
        
  return cv2_imshow(fr)

# %%
SmileDetect("3.jpg")
# Out:
# <PIL.Image.Image image mode=RGB size=216x234 at 0x7F8AC7C9A0D0>
